# %% [markdown]
# ## 1. Import des bibliotheques

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import matplotlib.pyplot as plt
import folium
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## 2. Charger les datasets

# %%
df_a = pd.read_csv("Arkansas/Arkansas_full_clean.csv")
df_c =pd.read_csv("california/California_combined_cleaned.csv")

# %% [markdown]
# ## 3. Explanatory data analysis

# %%
#l'Arkansas
df_a.info()
df_a.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9218 entries, 0 to 9217
# Columns: 364 entries, B11_T0 to crop_name
# dtypes: float64(362), int64(1), str(1)
# memory usage: 25.6 MB
#    B11_T0  B11_T1  B11_T10  B11_T11  B11_T12  B11_T13  B11_T14  B11_T15  \
# 0  3758.0  4060.0   6824.0   4118.0   5594.0   5586.0   6487.0      0.0
# 1  3185.5  3591.5   6134.0   3803.0   6019.5   5473.0   5635.5   3500.5
# 2  3063.0  3285.5   3038.0   2816.5   2981.0   3013.5   3468.0      0.0
# 3  2196.0  3534.0   5513.5   3020.0   3690.5   5059.0   6081.5      0.0
# 4  3268.0  3586.0   4803.0   3734.5      0.0      0.0   4277.0      0.0
#
#    B11_T16  B11_T17  ...   B8_T4   B8_T5   B8_T6   B8_T7   B8_T8   B8_T9  \
# 0   4378.0   3828.5  ...     0.0  7660.0  2674.0  3207.0  3220.0  3489.0
# 1   2872.0   2611.0  ...     0.0  8188.0  2975.0  3567.0  3024.0  2976.0
# 2   3210.5   3494.0  ...  9956.0  4626.0  2666.0  3808.0  3793.0  3913.0
# 3   5417.0   1875.0  ...     0.0  3579.0  2370.0  2834.0  3135.0  4868.0
# 4   5297.0   6177.5  ...     0.0  3162.0  2406.0     0.0  3542.0  3498.0
#
#    crop_label   latitude  longitude  crop_name
# 0           5  34.403047 -91.417880   Soybeans
# 1           1  34.296665 -91.354877       Corn
# 2           5  34.327085 -91.512739   Soybeans
# 3           3  35.744828 -90.708118       Rice
# 4           2  35.681737 -90.577141     Cotton
#
# [5 rows x 364 columns]

# %%
#ordonner les colonnes
nouvel_ordre = [
    'B2_T0','B3_T0','B4_T0','B5_T0','B6_T0','B7_T0','B8_T0','B8A_T0','B11_T0','B12_T0',
    'B2_T1','B3_T1','B4_T1','B5_T1','B6_T1','B7_T1','B8_T1','B8A_T1','B11_T1','B12_T1',
    'B2_T2','B3_T2','B4_T2','B5_T2','B6_T2','B7_T2','B8_T2','B8A_T2','B11_T2','B12_T2',
    'B2_T3','B3_T3','B4_T3','B5_T3','B6_T3','B7_T3','B8_T3','B8A_T3','B11_T3','B12_T3',
    'B2_T4','B3_T4','B4_T4','B5_T4','B6_T4','B7_T4','B8_T4','B8A_T4','B11_T4','B12_T4',
    'B2_T5','B3_T5','B4_T5','B5_T5','B6_T5','B7_T5','B8_T5','B8A_T5','B11_T5','B12_T5',
    'B2_T6','B3_T6','B4_T6','B5_T6','B6_T6','B7_T6','B8_T6','B8A_T6','B11_T6','B12_T6',
    'B2_T7','B3_T7','B4_T7','B5_T7','B6_T7','B7_T7','B8_T7','B8A_T7','B11_T7','B12_T7',
    'B2_T8','B3_T8','B4_T8','B5_T8','B6_T8','B7_T8','B8_T8','B8A_T8','B11_T8','B12_T8',
    'B2_T9','B3_T9','B4_T9','B5_T9','B6_T9','B7_T9','B8_T9','B8A_T9','B11_T9','B12_T9',
    'B2_T10','B3_T10','B4_T10','B5_T10','B6_T10','B7_T10','B8_T10','B8A_T10','B11_T10','B12_T10',
    'B2_T11','B3_T11','B4_T11','B5_T11','B6_T11','B7_T11','B8_T11','B8A_T11','B11_T11','B12_T11',
    'B2_T12','B3_T12','B4_T12','B5_T12','B6_T12','B7_T12','B8_T12','B8A_T12','B11_T12','B12_T12',
    'B2_T13','B3_T13','B4_T13','B5_T13','B6_T13','B7_T13','B8_T13','B8A_T13','B11_T13','B12_T13',
    'B2_T14','B3_T14','B4_T14','B5_T14','B6_T14','B7_T14','B8_T14','B8A_T14','B11_T14','B12_T14',
    'B2_T15','B3_T15','B4_T15','B5_T15','B6_T15','B7_T15','B8_T15','B8A_T15','B11_T15','B12_T15',
    'B2_T16','B3_T16','B4_T16','B5_T16','B6_T16','B7_T16','B8_T16','B8A_T16','B11_T16','B12_T16',
    'B2_T17','B3_T17','B4_T17','B5_T17','B6_T17','B7_T17','B8_T17','B8A_T17','B11_T17','B12_T17',
    'B2_T18','B3_T18','B4_T18','B5_T18','B6_T18','B7_T18','B8_T18','B8A_T18','B11_T18','B12_T18',
    'B2_T19','B3_T19','B4_T19','B5_T19','B6_T19','B7_T19','B8_T19','B8A_T19','B11_T19','B12_T19',
    'B2_T20','B3_T20','B4_T20','B5_T20','B6_T20','B7_T20','B8_T20','B8A_T20','B11_T20','B12_T20',
    'B2_T21','B3_T21','B4_T21','B5_T21','B6_T21','B7_T21','B8_T21','B8A_T21','B11_T21','B12_T21',
    'B2_T22','B3_T22','B4_T22','B5_T22','B6_T22','B7_T22','B8_T22','B8A_T22','B11_T22','B12_T22',
    'B2_T23','B3_T23','B4_T23','B5_T23','B6_T23','B7_T23','B8_T23','B8A_T23','B11_T23','B12_T23',
    'B2_T24','B3_T24','B4_T24','B5_T24','B6_T24','B7_T24','B8_T24','B8A_T24','B11_T24','B12_T24',
    'B2_T25','B3_T25','B4_T25','B5_T25','B6_T25','B7_T25','B8_T25','B8A_T25','B11_T25','B12_T25',
    'B2_T26','B3_T26','B4_T26','B5_T26','B6_T26','B7_T26','B8_T26','B8A_T26','B11_T26','B12_T26',
    'B2_T27','B3_T27','B4_T27','B5_T27','B6_T27','B7_T27','B8_T27','B8A_T27','B11_T27','B12_T27',
    'B2_T28','B3_T28','B4_T28','B5_T28','B6_T28','B7_T28','B8_T28','B8A_T28','B11_T28','B12_T28',
    'B2_T29','B3_T29','B4_T29','B5_T29','B6_T29','B7_T29','B8_T29','B8A_T29','B11_T29','B12_T29',
    'B2_T30','B3_T30','B4_T30','B5_T30','B6_T30','B7_T30','B8_T30','B8A_T30','B11_T30','B12_T30',
    'B2_T31','B3_T31','B4_T31','B5_T31','B6_T31','B7_T31','B8_T31','B8A_T31','B11_T31','B12_T31',
    'B2_T32','B3_T32','B4_T32','B5_T32','B6_T32','B7_T32','B8_T32','B8A_T32','B11_T32','B12_T32',
    'B2_T33','B3_T33','B4_T33','B5_T33','B6_T33','B7_T33','B8_T33','B8A_T33','B11_T33','B12_T33',
    'B2_T34','B3_T34','B4_T34','B5_T34','B6_T34','B7_T34','B8_T34','B8A_T34','B11_T34','B12_T34',
    'B2_T35','B3_T35','B4_T35','B5_T35','B6_T35','B7_T35','B8_T35','B8A_T35','B11_T35','B12_T35',
    'crop_label','latitude','longitude','crop_name'
]
df_a=df_a[nouvel_ordre]

# %%
df_a.head()
# Out:
#     B2_T0   B3_T0   B4_T0   B5_T0   B6_T0   B7_T0   B8_T0  B8A_T0  B11_T0  \
# 0  1836.0  2042.0  2412.0  2616.0  2753.0  2920.0  3186.0  3215.0  3758.0
# 1  1647.0  1908.0  2099.0  2438.0  2752.0  2925.5  3122.0  3092.0  3185.5
# 2  1655.0  1878.5  2135.0  2279.5  2724.5  2947.5  3587.0  3190.0  3063.0
# 3  1817.5  1984.0  2207.0  2458.5  2499.5  2613.0  2731.0  2754.5  2196.0
# 4  1456.0  1630.0  1704.0  2031.0  2475.0  2684.0  3062.0  2971.0  3268.0
#
#    B12_T0  ...  B6_T35  B7_T35  B8_T35  B8A_T35  B11_T35  B12_T35  crop_label  \
# 0  3099.0  ...  2751.0  2963.0  3288.0   3227.0   3578.0   2796.0           5
# 1  2471.0  ...  2733.0  2877.0  3073.0   3093.5   2923.5   2274.0           1
# 2  2307.0  ...  2812.0  3246.5  4146.0   3495.5   3018.5   2285.0           5
# 3  1753.5  ...  2695.0  2776.5  2809.0   3044.5   2978.5   2389.0           3
# 4  2510.0  ...  3399.0  3661.0  4022.0   3991.0   3389.0   2462.0           2
#
#     latitude  longitude  crop_name
# 0  34.403047 -91.417880   Soybeans
# 1  34.296665 -91.354877       Corn
# 2  34.327085 -91.512739   Soybeans
# 3  35.744828 -90.708118       Rice
# 4  35.681737 -90.577141     Cotton
#
# [5 rows x 364 columns]

# %%
df_a['crop_name'].value_counts()
# Out:
# crop_name
# Soybeans    4873
# Rice        1743
# Corn        1623
# Cotton       730
# Others       249
# Name: count, dtype: int64

# %%
df_a['crop_label'].value_counts()
# Out:
# crop_label
# 5      4873
# 3      1743
# 1      1623
# 2       730
# 26       72
# 190      31
# 24       30
# 4        27
# 121      25
# 122      19
# 61       16
# 37        8
# 123       8
# 176       5
# 111       2
# 59        2
# 10        1
# 124       1
# 74        1
# 195       1
# Name: count, dtype: int64

# %%
map = folium.Map(location=[df_a['latitude'].mean(), df_a['longitude'].mean()], zoom_start=10)
for i in range(len(df_a)):
    folium.CircleMarker(
        location=[df_a.iloc[i]['latitude'],df_a.iloc[i]['longitude']],
        radius=2
    ).add_to(map)

map.save("map.html")

# %% [markdown]
# # 3.Le modele

# %% [markdown]
# ## 3.1 L'arkansas

# %%
print(df_a.columns.tolist())
# Out:
# ['B2_T0', 'B3_T0', 'B4_T0', 'B5_T0', 'B6_T0', 'B7_T0', 'B8_T0', 'B8A_T0', 'B11_T0', 'B12_T0', 'B2_T1', 'B3_T1', 'B4_T1', 'B5_T1', 'B6_T1', 'B7_T1', 'B8_T1', 'B8A_T1', 'B11_T1', 'B12_T1', 'B2_T2', 'B3_T2', 'B4_T2', 'B5_T2', 'B6_T2', 'B7_T2', 'B8_T2', 'B8A_T2', 'B11_T2', 'B12_T2', 'B2_T3', 'B3_T3', 'B4_T3', 'B5_T3', 'B6_T3', 'B7_T3', 'B8_T3', 'B8A_T3', 'B11_T3', 'B12_T3', 'B2_T4', 'B3_T4', 'B4_T4', 'B5_T4', 'B6_T4', 'B7_T4', 'B8_T4', 'B8A_T4', 'B11_T4', 'B12_T4', 'B2_T5', 'B3_T5', 'B4_T5', 'B5_T5', 'B6_T5', 'B7_T5', 'B8_T5', 'B8A_T5', 'B11_T5', 'B12_T5', 'B2_T6', 'B3_T6', 'B4_T6', 'B5_T6', 'B6_T6', 'B7_T6', 'B8_T6', 'B8A_T6', 'B11_T6', 'B12_T6', 'B2_T7', 'B3_T7', 'B4_T7', 'B5_T7', 'B6_T7', 'B7_T7', 'B8_T7', 'B8A_T7', 'B11_T7', 'B12_T7', 'B2_T8', 'B3_T8', 'B4_T8', 'B5_T8', 'B6_T8', 'B7_T8', 'B8_T8', 'B8A_T8', 'B11_T8', 'B12_T8', 'B2_T9', 'B3_T9', 'B4_T9', 'B5_T9', 'B6_T9', 'B7_T9', 'B8_T9', 'B8A_T9', 'B11_T9', 'B12_T9', 'B2_T10', 'B3_T10', 'B4_T10', 'B5_T10', 'B6_T10', 'B7_T10', 'B8_T10', 'B8A_T10', 'B11_T10', 'B12_T10', 'B2_T11', 'B3_T11', 'B4_T11', 'B5_T11', 'B6_T11', 'B7_T11', 'B8_T11', 'B8A_T11', 'B11_T11', 'B12_T11', 'B2_T12', 'B3_T12', 'B4_T12', 'B5_T12', 'B6_T12', 'B7_T12', 'B8_T12', 'B8A_T12', 'B11_T12', 'B12_T12', 'B2_T13', 'B3_T13', 'B4_T13', 'B5_T13', 'B6_T13', 'B7_T13', 'B8_T13', 'B8A_T13', 'B11_T13', 'B12_T13', 'B2_T14', 'B3_T14', 'B4_T14', 'B5_T14', 'B6_T14', 'B7_T14', 'B8_T14', 'B8A_T14', 'B11_T14', 'B12_T14', 'B2_T15', 'B3_T15', 'B4_T15', 'B5_T15', 'B6_T15', 'B7_T15', 'B8_T15', 'B8A_T15', 'B11_T15', 'B12_T15', 'B2_T16', 'B3_T16', 'B4_T16', 'B5_T16', 'B6_T16', 'B7_T16', 'B8_T16', 'B8A_T16', 'B11_T16', 'B12_T16', 'B2_T17', 'B3_T17', 'B4_T17', 'B5_T17', 'B6_T17', 'B7_T17', 'B8_T17', 'B8A_T17', 'B11_T17', 'B12_T17', 'B2_T18', 'B3_T18', 'B4_T18', 'B5_T18', 'B6_T18', 'B7_T18', 'B8_T18', 'B8A_T18', 'B11_T18', 'B12_T18', 'B2_T19', 'B3_T19', 'B4_T19', 'B5_T19', 'B6_T19', 'B7_T19', 'B8_T19', 'B8A_T19', 'B11_T19', 'B12_T19', 'B2_T20', 'B3_T20', 'B4_T20', 'B5_T20', 'B6_T20', 'B7_T20', 'B8_T20', 'B8A_T20', 'B11_T20', 'B12_T20', 'B2_T21', 'B3_T21', 'B4_T21', 'B5_T21', 'B6_T21', 'B7_T21', 'B8_T21', 'B8A_T21', 'B11_T21', 'B12_T21', 'B2_T22', 'B3_T22', 'B4_T22', 'B5_T22', 'B6_T22', 'B7_T22', 'B8_T22', 'B8A_T22', 'B11_T22', 'B12_T22', 'B2_T23', 'B3_T23', 'B4_T23', 'B5_T23', 'B6_T23', 'B7_T23', 'B8_T23', 'B8A_T23', 'B11_T23', 'B12_T23', 'B2_T24', 'B3_T24', 'B4_T24', 'B5_T24', 'B6_T24', 'B7_T24', 'B8_T24', 'B8A_T24', 'B11_T24', 'B12_T24', 'B2_T25', 'B3_T25', 'B4_T25', 'B5_T25', 'B6_T25', 'B7_T25', 'B8_T25', 'B8A_T25', 'B11_T25', 'B12_T25', 'B2_T26', 'B3_T26', 'B4_T26', 'B5_T26', 'B6_T26', 'B7_T26', 'B8_T26', 'B8A_T26', 'B11_T26', 'B12_T26', 'B2_T27', 'B3_T27', 'B4_T27', 'B5_T27', 'B6_T27', 'B7_T27', 'B8_T27', 'B8A_T27', 'B11_T27', 'B12_T27', 'B2_T28', 'B3_T28', 'B4_T28', 'B5_T28', 'B6_T28', 'B7_T28', 'B8_T28', 'B8A_T28', 'B11_T28', 'B12_T28', 'B2_T29', 'B3_T29', 'B4_T29', 'B5_T29', 'B6_T29', 'B7_T29', 'B8_T29', 'B8A_T29', 'B11_T29', 'B12_T29', 'B2_T30', 'B3_T30', 'B4_T30', 'B5_T30', 'B6_T30', 'B7_T30', 'B8_T30', 'B8A_T30', 'B11_T30', 'B12_T30', 'B2_T31', 'B3_T31', 'B4_T31', 'B5_T31', 'B6_T31', 'B7_T31', 'B8_T31', 'B8A_T31', 'B11_T31', 'B12_T31', 'B2_T32', 'B3_T32', 'B4_T32', 'B5_T32', 'B6_T32', 'B7_T32', 'B8_T32', 'B8A_T32', 'B11_T32', 'B12_T32', 'B2_T33', 'B3_T33', 'B4_T33', 'B5_T33', 'B6_T33', 'B7_T33', 'B8_T33', 'B8A_T33', 'B11_T33', 'B12_T33', 'B2_T34', 'B3_T34', 'B4_T34', 'B5_T34', 'B6_T34', 'B7_T34', 'B8_T34', 'B8A_T34', 'B11_T34', 'B12_T34', 'B2_T35', 'B3_T35', 'B4_T35', 'B5_T35', 'B6_T35', 'B7_T35', 'B8_T35', 'B8A_T35', 'B11_T35', 'B12_T35', 'crop_label', 'latitude', 'longitude', 'crop_name']

# %%
#separer x et y
df_a_x = df_a.drop(columns=['crop_label','latitude','longitude','crop_name'])
X_a = df_a_x.values
df_a_y =df_a[['crop_name','crop_label']]
df_a_y.loc[df_a['crop_name'] == 'Others', 'crop_label'] = 0
df_a_y.loc[df_a['crop_label'] == 5, 'crop_label'] = 4
y_a = df_a_y['crop_label'].values

# %%
#reshape
X_a = X_a.reshape(-1,36,10)  

#normalisation
X_a = X_a / np.max(X_a)

# %%
mask = (X_a != 0).astype(float)

# %%
# separer le dataset en :une partie pour entrainer et valider et une partie pour tester le modele
X_a_train, X_a_test, y_a_train, y_a_test, mask_a_train, mask_a_test = train_test_split(
    X_a, y_a, mask, test_size=0.15, random_state=42
)

# %%
#Le CNN
def CNNBlock(x):
    shortcut = x
    
    x = layers.Conv1D(filters=x.shape[-1], kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv1D(filters=x.shape[-1], kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])  #shortcut 
    x = layers.ReLU()(x)

    return x

# %%
#Transformer
def TransformerBlock(x, num_heads=5):
    dim = x.shape[-1]

    # Multi-head attention
    attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=dim)(x, x)
    x = layers.Add()([x, attn])
    x = layers.LayerNormalization()(x)

    # Feed Forward
    ff = layers.Dense(dim, activation='relu')(x)
    ff = layers.Dense(dim)(ff)

    x = layers.Add()([x, ff])
    x = layers.LayerNormalization()(x)

    return x

# %%
def ALPE(x, mask):
    

    x = layers.Multiply()([x, mask])

    x = layers.Conv1D(filters=x.shape[-1], kernel_size=3, padding='same')(x)

    # Attention simple (approximation ECA)
    weights = layers.GlobalAveragePooling1D()(x)
    weights = layers.Dense(x.shape[-1], activation='sigmoid')(weights)
    weights = layers.Reshape((1, x.shape[-1]))(weights)

    x = layers.Multiply()([x, weights])

    return x

# %%
def CTFusion(x):
    cnn_out = CNNBlock(x)
    trans_out = TransformerBlock(x)

    return layers.Add()([cnn_out, trans_out])

# %%
def build_MCTNet(input_shape=(36, 10), num_classes=5):
    inputs = tf.keras.Input(shape=input_shape)
    mask = tf.keras.Input(shape=input_shape)

    
    x = ALPE(inputs, mask)

   
    x = CTFusion(x)
    x = layers.MaxPooling1D(pool_size=2)(x)

    x = CTFusion(x)
    x = layers.MaxPooling1D(pool_size=2)(x)

    x = CTFusion(x)

   
    x = layers.GlobalMaxPooling1D()(x)

    # Classifier
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=[inputs, mask], outputs=outputs)

    return model

# %%
model = build_MCTNet()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_16      │ (None, 36, 10)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_17      │ (None, 36, 10)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_16         │ (None, 36, 10)    │          0 │ input_layer_16[0… │
# │ (Multiply)          │                   │            │ input_layer_17[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_56 (Conv1D)  │ (None, 36, 10)    │        310 │ multiply_16[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 10)        │          0 │ conv1d_56[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_64 (Dense)    │ (None, 10)        │        110 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 1, 10)     │          0 │ dense_64[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_17         │ (None, 36, 10)    │          0 │ conv1d_56[0][0],  │
# │ (Multiply)          │                   │            │ reshape_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_57 (Conv1D)  │ (None, 36, 10)    │        310 │ multiply_17[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 36, 10)    │      2,160 │ multiply_17[0][0… │
# │ (MultiHeadAttentio… │                   │            │ multiply_17[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 10)    │         40 │ conv1d_57[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_97 (Add)        │ (None, 36, 10)    │          0 │ multiply_17[0][0… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_48 (ReLU)     │ (None, 36, 10)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 36, 10)    │         20 │ add_97[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_58 (Conv1D)  │ (None, 36, 10)    │        310 │ re_lu_48[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_65 (Dense)    │ (None, 36, 10)    │        110 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 10)    │         40 │ conv1d_58[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_66 (Dense)    │ (None, 36, 10)    │        110 │ dense_65[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_96 (Add)        │ (None, 36, 10)    │          0 │ batch_normalizat… │
# │                     │                   │            │ multiply_17[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_98 (Add)        │ (None, 36, 10)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_66[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_49 (ReLU)     │ (None, 36, 10)    │          0 │ add_96[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 36, 10)    │         20 │ add_98[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_99 (Add)        │ (None, 36, 10)    │          0 │ re_lu_49[0][0],   │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_16    │ (None, 18, 10)    │          0 │ add_99[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_59 (Conv1D)  │ (None, 18, 10)    │        310 │ max_pooling1d_16… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 18, 10)    │      2,160 │ max_pooling1d_16… │
# │ (MultiHeadAttentio… │                   │            │ max_pooling1d_16… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 10)    │         40 │ conv1d_59[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_101 (Add)       │ (None, 18, 10)    │          0 │ max_pooling1d_16… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_50 (ReLU)     │ (None, 18, 10)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 18, 10)    │         20 │ add_101[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_60 (Conv1D)  │ (None, 18, 10)    │        310 │ re_lu_50[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_67 (Dense)    │ (None, 18, 10)    │        110 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 10)    │         40 │ conv1d_60[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_68 (Dense)    │ (None, 18, 10)    │        110 │ dense_67[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_100 (Add)       │ (None, 18, 10)    │          0 │ batch_normalizat… │
# │                     │                   │            │ max_pooling1d_16… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_102 (Add)       │ (None, 18, 10)    │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_68[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_51 (ReLU)     │ (None, 18, 10)    │          0 │ add_100[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 18, 10)    │         20 │ add_102[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_103 (Add)       │ (None, 18, 10)    │          0 │ re_lu_51[0][0],   │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_17    │ (None, 9, 10)     │          0 │ add_103[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_61 (Conv1D)  │ (None, 9, 10)     │        310 │ max_pooling1d_17… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 9, 10)     │      2,160 │ max_pooling1d_17… │
# │ (MultiHeadAttentio… │                   │            │ max_pooling1d_17… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 10)     │         40 │ conv1d_61[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_105 (Add)       │ (None, 9, 10)     │          0 │ max_pooling1d_17… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 9, 10)     │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 9, 10)     │         20 │ add_105[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_62 (Conv1D)  │ (None, 9, 10)     │        310 │ re_lu_52[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_69 (Dense)    │ (None, 9, 10)     │        110 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 10)     │         40 │ conv1d_62[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_70 (Dense)    │ (None, 9, 10)     │        110 │ dense_69[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_104 (Add)       │ (None, 9, 10)     │          0 │ batch_normalizat… │
# │                     │                   │            │ max_pooling1d_17… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_106 (Add)       │ (None, 9, 10)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_70[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 9, 10)     │          0 │ add_104[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 9, 10)     │         20 │ add_106[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_107 (Add)       │ (None, 9, 10)     │          0 │ re_lu_53[0][0],   │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 10)        │          0 │ add_107[0][0]     │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_71 (Dense)    │ (None, 5)         │         55 │ global_max_pooli… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,835 (38.42 KB)
#  Trainable params: 9,715 (37.95 KB)
#  Non-trainable params: 120 (480.00 B)

# %%
model.fit(
    [X_a_train, mask_a_train],
    y_a_train,
    validation_data=([X_a_test, mask_a_test], y_a_test),
    epochs=200,
    batch_size=32
)
# Out:
# Epoch 1/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.6692 - loss: 0.9099 - val_accuracy: 0.6074 - val_loss: 1.1375
# Epoch 2/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.8389 - loss: 0.4892 - val_accuracy: 0.7513 - val_loss: 0.7690
# Epoch 3/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8781 - loss: 0.3755 - val_accuracy: 0.8706 - val_loss: 0.4317
# Epoch 4/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.8975 - loss: 0.3243 - val_accuracy: 0.8633 - val_loss: 0.4581
# Epoch 5/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9052 - loss: 0.3006 - val_accuracy: 0.8952 - val_loss: 0.3589
# Epoch 6/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9145 - loss: 0.2803 - val_accuracy: 0.8257 - val_loss: 0.5450
# Epoch 7/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9164 - loss: 0.2641 - val_accuracy: 0.8735 - val_loss: 0.4443
# Epoch 8/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9216 - loss: 0.2538 - val_accuracy: 0.8966 - val_loss: 0.3426
# Epoch 9/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9262 - loss: 0.2429 - val_accuracy: 0.8821 - val_loss: 0.4133
# Epoch 10/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9246 - loss: 0.2381 - val_accuracy: 0.7845 - val_loss: 0.6052
# Epoch 11/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9285 - loss: 0.2273 - val_accuracy: 0.9154 - val_loss: 0.2741
# Epoch 12/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9295 - loss: 0.2226 - val_accuracy: 0.8583 - val_loss: 0.4872
# Epoch 13/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9303 - loss: 0.2166 - val_accuracy: 0.9017 - val_loss: 0.3225
# Epoch 14/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9315 - loss: 0.2168 - val_accuracy: 0.8720 - val_loss: 0.4614
# Epoch 15/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9336 - loss: 0.2076 - val_accuracy: 0.9096 - val_loss: 0.3121
# Epoch 16/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9339 - loss: 0.2093 - val_accuracy: 0.8901 - val_loss: 0.3793
# Epoch 17/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9353 - loss: 0.1984 - val_accuracy: 0.9118 - val_loss: 0.3123
# Epoch 18/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9354 - loss: 0.2009 - val_accuracy: 0.9082 - val_loss: 0.3137
# Epoch 19/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9335 - loss: 0.2027 - val_accuracy: 0.9176 - val_loss: 0.3001
# Epoch 20/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9369 - loss: 0.1978 - val_accuracy: 0.9125 - val_loss: 0.2896
# Epoch 21/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9389 - loss: 0.1939 - val_accuracy: 0.8988 - val_loss: 0.3401
# Epoch 22/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9376 - loss: 0.1899 - val_accuracy: 0.8930 - val_loss: 0.3460
# Epoch 23/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9376 - loss: 0.1862 - val_accuracy: 0.9183 - val_loss: 0.2847
# Epoch 24/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9398 - loss: 0.1825 - val_accuracy: 0.7542 - val_loss: 0.9146
# Epoch 25/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9421 - loss: 0.1763 - val_accuracy: 0.9103 - val_loss: 0.2966
# Epoch 26/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9429 - loss: 0.1801 - val_accuracy: 0.9132 - val_loss: 0.3201
# Epoch 27/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9431 - loss: 0.1756 - val_accuracy: 0.8445 - val_loss: 0.4658
# Epoch 28/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9431 - loss: 0.1726 - val_accuracy: 0.9168 - val_loss: 0.2847
# Epoch 29/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9408 - loss: 0.1749 - val_accuracy: 0.9154 - val_loss: 0.3098
# Epoch 30/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9449 - loss: 0.1647 - val_accuracy: 0.9031 - val_loss: 0.3493
# Epoch 31/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9456 - loss: 0.1658 - val_accuracy: 0.7563 - val_loss: 0.6733
# Epoch 32/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9433 - loss: 0.1660 - val_accuracy: 0.8908 - val_loss: 0.3797
# Epoch 33/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9445 - loss: 0.1600 - val_accuracy: 0.9132 - val_loss: 0.3191
# Epoch 34/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9447 - loss: 0.1607 - val_accuracy: 0.9002 - val_loss: 0.3184
# Epoch 35/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9461 - loss: 0.1595 - val_accuracy: 0.9082 - val_loss: 0.3159
# Epoch 36/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9473 - loss: 0.1504 - val_accuracy: 0.8344 - val_loss: 0.5387
# Epoch 37/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9466 - loss: 0.1555 - val_accuracy: 0.8380 - val_loss: 0.6336
# Epoch 38/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9488 - loss: 0.1502 - val_accuracy: 0.9132 - val_loss: 0.3277
# Epoch 39/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9482 - loss: 0.1486 - val_accuracy: 0.9024 - val_loss: 0.3537
# Epoch 40/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.9510 - loss: 0.1470 - val_accuracy: 0.8959 - val_loss: 0.3351
# Epoch 41/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9526 - loss: 0.1443 - val_accuracy: 0.8908 - val_loss: 0.4298
# Epoch 42/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9516 - loss: 0.1425 - val_accuracy: 0.9017 - val_loss: 0.3618
# Epoch 43/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9519 - loss: 0.1454 - val_accuracy: 0.9255 - val_loss: 0.3140
# Epoch 44/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9524 - loss: 0.1381 - val_accuracy: 0.9103 - val_loss: 0.3493
# Epoch 45/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9512 - loss: 0.1384 - val_accuracy: 0.9125 - val_loss: 0.3608
# Epoch 46/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9533 - loss: 0.1353 - val_accuracy: 0.9096 - val_loss: 0.3460
# Epoch 47/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.9530 - loss: 0.1339 - val_accuracy: 0.8785 - val_loss: 0.4292
# Epoch 48/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9546 - loss: 0.1335 - val_accuracy: 0.8735 - val_loss: 0.5307
# Epoch 49/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9546 - loss: 0.1335 - val_accuracy: 0.6334 - val_loss: 2.0350
# Epoch 50/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9526 - loss: 0.1328 - val_accuracy: 0.8814 - val_loss: 0.3985
# Epoch 51/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9518 - loss: 0.1318 - val_accuracy: 0.8865 - val_loss: 0.4556
# Epoch 52/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9562 - loss: 0.1262 - val_accuracy: 0.9096 - val_loss: 0.3406
# Epoch 53/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9547 - loss: 0.1282 - val_accuracy: 0.9111 - val_loss: 0.3397
# Epoch 54/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9563 - loss: 0.1241 - val_accuracy: 0.8995 - val_loss: 0.3620
# Epoch 55/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9574 - loss: 0.1226 - val_accuracy: 0.9176 - val_loss: 0.3401
# Epoch 56/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9575 - loss: 0.1191 - val_accuracy: 0.9154 - val_loss: 0.3390
# Epoch 57/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9581 - loss: 0.1204 - val_accuracy: 0.8973 - val_loss: 0.4510
# Epoch 58/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9544 - loss: 0.1217 - val_accuracy: 0.9002 - val_loss: 0.3784
# Epoch 59/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9581 - loss: 0.1169 - val_accuracy: 0.8821 - val_loss: 0.4392
# Epoch 60/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9617 - loss: 0.1137 - val_accuracy: 0.8677 - val_loss: 0.4174
# Epoch 61/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9609 - loss: 0.1112 - val_accuracy: 0.9161 - val_loss: 0.3523
# Epoch 62/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9578 - loss: 0.1159 - val_accuracy: 0.9111 - val_loss: 0.4237
# Epoch 63/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9611 - loss: 0.1073 - val_accuracy: 0.8930 - val_loss: 0.4279
# Epoch 64/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9570 - loss: 0.1190 - val_accuracy: 0.9125 - val_loss: 0.3496
# Epoch 65/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9617 - loss: 0.1051 - val_accuracy: 0.8720 - val_loss: 0.4284
# Epoch 66/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9618 - loss: 0.1045 - val_accuracy: 0.9031 - val_loss: 0.4050
# Epoch 67/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9627 - loss: 0.1038 - val_accuracy: 0.8713 - val_loss: 0.4676
# Epoch 68/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.9630 - loss: 0.1026 - val_accuracy: 0.9161 - val_loss: 0.3995
# Epoch 69/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9659 - loss: 0.0971 - val_accuracy: 0.9060 - val_loss: 0.3900
# Epoch 70/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9611 - loss: 0.1110 - val_accuracy: 0.8807 - val_loss: 0.4265
# Epoch 71/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9650 - loss: 0.1033 - val_accuracy: 0.9161 - val_loss: 0.3804
# Epoch 72/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.9643 - loss: 0.0975 - val_accuracy: 0.9009 - val_loss: 0.3822
# Epoch 73/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9668 - loss: 0.0959 - val_accuracy: 0.8937 - val_loss: 0.4749
# Epoch 74/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9648 - loss: 0.0946 - val_accuracy: 0.8619 - val_loss: 0.5870
# Epoch 75/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9678 - loss: 0.0907 - val_accuracy: 0.9046 - val_loss: 0.4044
# Epoch 76/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.9698 - loss: 0.0881 - val_accuracy: 0.9103 - val_loss: 0.4047
# Epoch 77/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.9680 - loss: 0.0916 - val_accuracy: 0.8980 - val_loss: 0.4058
# Epoch 78/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9650 - loss: 0.0922 - val_accuracy: 0.9176 - val_loss: 0.3827
# Epoch 79/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9671 - loss: 0.0901 - val_accuracy: 0.9002 - val_loss: 0.4817
# Epoch 80/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9676 - loss: 0.0925 - val_accuracy: 0.9161 - val_loss: 0.3847
# Epoch 81/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9657 - loss: 0.0916 - val_accuracy: 0.9009 - val_loss: 0.4288
# Epoch 82/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9634 - loss: 0.0967 - val_accuracy: 0.9161 - val_loss: 0.4360
# Epoch 83/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9657 - loss: 0.0941 - val_accuracy: 0.9082 - val_loss: 0.3693
# Epoch 84/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9712 - loss: 0.0852 - val_accuracy: 0.9147 - val_loss: 0.3695
# Epoch 85/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9703 - loss: 0.0856 - val_accuracy: 0.9096 - val_loss: 0.3826
# Epoch 86/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.9745 - loss: 0.0767 - val_accuracy: 0.8966 - val_loss: 0.4384
# Epoch 87/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9690 - loss: 0.0871 - val_accuracy: 0.8200 - val_loss: 0.8480
# Epoch 88/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9668 - loss: 0.0918 - val_accuracy: 0.9096 - val_loss: 0.4357
# Epoch 89/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9694 - loss: 0.0837 - val_accuracy: 0.9060 - val_loss: 0.4130
# Epoch 90/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9740 - loss: 0.0762 - val_accuracy: 0.8771 - val_loss: 0.5209
# Epoch 91/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9685 - loss: 0.0819 - val_accuracy: 0.9009 - val_loss: 0.3950
# Epoch 92/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9673 - loss: 0.0877 - val_accuracy: 0.9103 - val_loss: 0.4367
# Epoch 93/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9685 - loss: 0.0848 - val_accuracy: 0.9118 - val_loss: 0.4314
# Epoch 94/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9698 - loss: 0.0800 - val_accuracy: 0.9089 - val_loss: 0.3856
# Epoch 95/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9689 - loss: 0.0812 - val_accuracy: 0.9024 - val_loss: 0.5172
# Epoch 96/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9704 - loss: 0.0764 - val_accuracy: 0.9009 - val_loss: 0.4734
# Epoch 97/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9715 - loss: 0.0782 - val_accuracy: 0.8886 - val_loss: 0.5281
# Epoch 98/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9695 - loss: 0.0811 - val_accuracy: 0.8937 - val_loss: 0.5422
# Epoch 99/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9766 - loss: 0.0682 - val_accuracy: 0.8959 - val_loss: 0.4336
# Epoch 100/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9726 - loss: 0.0745 - val_accuracy: 0.9132 - val_loss: 0.4250
# Epoch 101/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9719 - loss: 0.0773 - val_accuracy: 0.9111 - val_loss: 0.4861
# Epoch 102/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9717 - loss: 0.0764 - val_accuracy: 0.8764 - val_loss: 0.5527
# Epoch 103/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9759 - loss: 0.0691 - val_accuracy: 0.8294 - val_loss: 0.6268
# Epoch 104/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9736 - loss: 0.0725 - val_accuracy: 0.8698 - val_loss: 0.5196
# Epoch 105/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9732 - loss: 0.0735 - val_accuracy: 0.9038 - val_loss: 0.4466
# Epoch 106/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9731 - loss: 0.0738 - val_accuracy: 0.9009 - val_loss: 0.5196
# Epoch 107/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9746 - loss: 0.0705 - val_accuracy: 0.9132 - val_loss: 0.4440
# Epoch 108/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9772 - loss: 0.0662 - val_accuracy: 0.9017 - val_loss: 0.4389
# Epoch 109/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9764 - loss: 0.0641 - val_accuracy: 0.8814 - val_loss: 0.5135
# Epoch 110/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9740 - loss: 0.0707 - val_accuracy: 0.9038 - val_loss: 0.4491
# Epoch 111/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9740 - loss: 0.0706 - val_accuracy: 0.8727 - val_loss: 0.6704
# Epoch 112/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9719 - loss: 0.0764 - val_accuracy: 0.9089 - val_loss: 0.4684
# Epoch 113/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9742 - loss: 0.0664 - val_accuracy: 0.8923 - val_loss: 0.4582
# Epoch 114/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9761 - loss: 0.0660 - val_accuracy: 0.8973 - val_loss: 0.5807
# Epoch 115/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9746 - loss: 0.0712 - val_accuracy: 0.9067 - val_loss: 0.4750
# Epoch 116/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9782 - loss: 0.0629 - val_accuracy: 0.8670 - val_loss: 0.6045
# Epoch 117/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9759 - loss: 0.0670 - val_accuracy: 0.9111 - val_loss: 0.4353
# Epoch 118/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9720 - loss: 0.0736 - val_accuracy: 0.9082 - val_loss: 0.4472
# Epoch 119/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9745 - loss: 0.0689 - val_accuracy: 0.9060 - val_loss: 0.4785
# Epoch 120/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9765 - loss: 0.0638 - val_accuracy: 0.8937 - val_loss: 0.4875
# Epoch 121/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9809 - loss: 0.0559 - val_accuracy: 0.8988 - val_loss: 0.4740
# Epoch 122/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9755 - loss: 0.0656 - val_accuracy: 0.9118 - val_loss: 0.4910
# Epoch 123/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9750 - loss: 0.0687 - val_accuracy: 0.8980 - val_loss: 0.5041
# Epoch 124/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9801 - loss: 0.0566 - val_accuracy: 0.9103 - val_loss: 0.4574
# Epoch 125/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9763 - loss: 0.0681 - val_accuracy: 0.8583 - val_loss: 0.6384
# Epoch 126/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9749 - loss: 0.0695 - val_accuracy: 0.8004 - val_loss: 0.7871
# Epoch 127/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9765 - loss: 0.0606 - val_accuracy: 0.9103 - val_loss: 0.4555
# Epoch 128/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9777 - loss: 0.0565 - val_accuracy: 0.9111 - val_loss: 0.4548
# Epoch 129/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9796 - loss: 0.0554 - val_accuracy: 0.9024 - val_loss: 0.4827
# Epoch 130/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9756 - loss: 0.0704 - val_accuracy: 0.8973 - val_loss: 0.5059
# Epoch 131/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9780 - loss: 0.0596 - val_accuracy: 0.9053 - val_loss: 0.4995
# Epoch 132/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9792 - loss: 0.0572 - val_accuracy: 0.8973 - val_loss: 0.5039
# Epoch 133/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9754 - loss: 0.0658 - val_accuracy: 0.8915 - val_loss: 0.5472
# Epoch 134/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9742 - loss: 0.0673 - val_accuracy: 0.8973 - val_loss: 0.4909
# Epoch 135/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9835 - loss: 0.0497 - val_accuracy: 0.9205 - val_loss: 0.4938
# Epoch 136/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9797 - loss: 0.0570 - val_accuracy: 0.9140 - val_loss: 0.4502
# Epoch 137/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9764 - loss: 0.0623 - val_accuracy: 0.8865 - val_loss: 0.5259
# Epoch 138/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9787 - loss: 0.0563 - val_accuracy: 0.9024 - val_loss: 0.5321
# Epoch 139/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9792 - loss: 0.0575 - val_accuracy: 0.9046 - val_loss: 0.4792
# Epoch 140/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9823 - loss: 0.0524 - val_accuracy: 0.8952 - val_loss: 0.5362
# Epoch 141/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9788 - loss: 0.0538 - val_accuracy: 0.8995 - val_loss: 0.5396
# Epoch 142/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9793 - loss: 0.0581 - val_accuracy: 0.9053 - val_loss: 0.5339
# Epoch 143/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9765 - loss: 0.0614 - val_accuracy: 0.8843 - val_loss: 0.5622
# Epoch 144/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9743 - loss: 0.0722 - val_accuracy: 0.9024 - val_loss: 0.5359
# Epoch 145/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9839 - loss: 0.0497 - val_accuracy: 0.9038 - val_loss: 0.6287
# Epoch 146/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9839 - loss: 0.0444 - val_accuracy: 0.9074 - val_loss: 0.5361
# Epoch 147/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9787 - loss: 0.0575 - val_accuracy: 0.7129 - val_loss: 1.3139
# Epoch 148/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9814 - loss: 0.0524 - val_accuracy: 0.9074 - val_loss: 0.5168
# Epoch 149/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9834 - loss: 0.0475 - val_accuracy: 0.8952 - val_loss: 0.5491
# Epoch 150/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9806 - loss: 0.0559 - val_accuracy: 0.9125 - val_loss: 0.5115
# Epoch 151/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9825 - loss: 0.0467 - val_accuracy: 0.9111 - val_loss: 0.5090
# Epoch 152/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9745 - loss: 0.0726 - val_accuracy: 0.8937 - val_loss: 0.5663
# Epoch 153/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9806 - loss: 0.0532 - val_accuracy: 0.8937 - val_loss: 0.6406
# Epoch 154/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9830 - loss: 0.0466 - val_accuracy: 0.8980 - val_loss: 0.5517
# Epoch 155/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9810 - loss: 0.0515 - val_accuracy: 0.8872 - val_loss: 0.6066
# Epoch 156/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9809 - loss: 0.0538 - val_accuracy: 0.8691 - val_loss: 0.7222
# Epoch 157/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9828 - loss: 0.0531 - val_accuracy: 0.8829 - val_loss: 0.5909
# Epoch 158/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9793 - loss: 0.0547 - val_accuracy: 0.9161 - val_loss: 0.5607
# Epoch 159/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9838 - loss: 0.0458 - val_accuracy: 0.9031 - val_loss: 0.5150
# Epoch 160/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9821 - loss: 0.0514 - val_accuracy: 0.8959 - val_loss: 0.5627
# Epoch 161/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9816 - loss: 0.0561 - val_accuracy: 0.8821 - val_loss: 0.6336
# Epoch 162/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9812 - loss: 0.0523 - val_accuracy: 0.9017 - val_loss: 0.5315
# Epoch 163/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9842 - loss: 0.0447 - val_accuracy: 0.9038 - val_loss: 0.5142
# Epoch 164/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9833 - loss: 0.0424 - val_accuracy: 0.8952 - val_loss: 0.5482
# Epoch 165/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.9819 - loss: 0.0500 - val_accuracy: 0.9132 - val_loss: 0.5169
# Epoch 166/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9837 - loss: 0.0427 - val_accuracy: 0.9038 - val_loss: 0.6238
# Epoch 167/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9782 - loss: 0.0572 - val_accuracy: 0.8113 - val_loss: 0.8443
# Epoch 168/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9750 - loss: 0.0638 - val_accuracy: 0.8901 - val_loss: 0.6927
# Epoch 169/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9815 - loss: 0.0540 - val_accuracy: 0.9038 - val_loss: 0.5337
# Epoch 170/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9848 - loss: 0.0449 - val_accuracy: 0.8901 - val_loss: 0.5492
# Epoch 171/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9835 - loss: 0.0463 - val_accuracy: 0.9053 - val_loss: 0.5859
# Epoch 172/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9798 - loss: 0.0549 - val_accuracy: 0.8915 - val_loss: 0.6550
# Epoch 173/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9847 - loss: 0.0434 - val_accuracy: 0.8959 - val_loss: 0.5622
# Epoch 174/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9765 - loss: 0.0629 - val_accuracy: 0.8995 - val_loss: 0.5498
# Epoch 175/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9819 - loss: 0.0500 - val_accuracy: 0.9111 - val_loss: 0.5701
# Epoch 176/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.9888 - loss: 0.0338 - val_accuracy: 0.9067 - val_loss: 0.5550
# Epoch 177/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9872 - loss: 0.0401 - val_accuracy: 0.9103 - val_loss: 0.5918
# Epoch 178/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9856 - loss: 0.0423 - val_accuracy: 0.8952 - val_loss: 0.5835
# Epoch 179/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9870 - loss: 0.0377 - val_accuracy: 0.8785 - val_loss: 0.6058
# Epoch 180/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9848 - loss: 0.0415 - val_accuracy: 0.8980 - val_loss: 0.5957
# Epoch 181/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9778 - loss: 0.0607 - val_accuracy: 0.9017 - val_loss: 0.5509
# Epoch 182/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9849 - loss: 0.0428 - val_accuracy: 0.9176 - val_loss: 0.5855
# Epoch 183/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9865 - loss: 0.0421 - val_accuracy: 0.8966 - val_loss: 0.5572
# Epoch 184/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9807 - loss: 0.0551 - val_accuracy: 0.8474 - val_loss: 0.9972
# Epoch 185/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9806 - loss: 0.0501 - val_accuracy: 0.9096 - val_loss: 0.5328
# Epoch 186/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9869 - loss: 0.0375 - val_accuracy: 0.8604 - val_loss: 0.6934
# Epoch 187/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9843 - loss: 0.0420 - val_accuracy: 0.9046 - val_loss: 0.5553
# Epoch 188/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9828 - loss: 0.0502 - val_accuracy: 0.7939 - val_loss: 0.9625
# Epoch 189/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9863 - loss: 0.0407 - val_accuracy: 0.9147 - val_loss: 0.5463
# Epoch 190/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9840 - loss: 0.0431 - val_accuracy: 0.8944 - val_loss: 0.5284
# Epoch 191/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9848 - loss: 0.0384 - val_accuracy: 0.8923 - val_loss: 0.5717
# Epoch 192/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9782 - loss: 0.0610 - val_accuracy: 0.8814 - val_loss: 0.8326
# Epoch 193/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9835 - loss: 0.0472 - val_accuracy: 0.9053 - val_loss: 0.5397
# Epoch 194/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9812 - loss: 0.0508 - val_accuracy: 0.9002 - val_loss: 0.5412
# Epoch 195/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9897 - loss: 0.0319 - val_accuracy: 0.9009 - val_loss: 0.6294
# Epoch 196/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.9825 - loss: 0.0485 - val_accuracy: 0.8923 - val_loss: 0.7120
# Epoch 197/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9817 - loss: 0.0527 - val_accuracy: 0.8901 - val_loss: 0.5943
# Epoch 198/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.9833 - loss: 0.0449 - val_accuracy: 0.9009 - val_loss: 0.6007
# Epoch 199/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9851 - loss: 0.0451 - val_accuracy: 0.9096 - val_loss: 0.5440
# Epoch 200/200
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9870 - loss: 0.0374 - val_accuracy: 0.8995 - val_loss: 0.5347

# %% [markdown]
# # 4. Metriques et evaluations

# %%
y_a_pred = model.predict([X_a_test, mask_a_test])
y_a_pred = y_a_pred.argmax(axis=1)

oa = accuracy_score(y_a_test, y_a_pred)
f1 = f1_score(y_a_test, y_a_pred, average='macro')
kappa = cohen_kappa_score(y_a_test, y_a_pred)

print("OA:", oa)
print("F1:", f1)
print("Kappa:", kappa)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# OA: 0.8994938539407086
# F1: 0.8194484695098213
# Kappa: 0.8452854545615508

# %%
# Confusion Matrix 
labels = ["Soybeans", "Rice", "Cotton", "Corn", "Others"]
cm = confusion_matrix(y_a_test, y_a_pred,labels=[4,3,2,1,0])
cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_norm,display_labels=labels)
disp.plot(cmap="Blues")
plt.title("Matrice de confusion")
plt.show()
